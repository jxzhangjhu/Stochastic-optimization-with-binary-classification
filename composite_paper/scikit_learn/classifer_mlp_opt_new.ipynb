# %% [markdown]
# # Data Collection

# %%
from math import*
import __main__
global PI
import os
import time
PI=float(acos(-1))

import random
import numpy as np
import multiprocessing as mp

import matplotlib.pyplot as plt
# %matplotlib inline

rs_number = 123
random.seed(rs_number)

data_size = 100000;

random_selection = 0

if random_selection==0:
    ''' random selection'''
    datasets = np.random.randint(1, 10, size=[data_size, 8])
#     data_input = arr.tolist()
#     datasets = arr
else:
    '''latin hypercube sampling'''


def ssh(num):
#     global datasets
#     arr = np.random.randint(1, 10, size=[data_size, 8])
#     datasets = arr.tolist()
    ply_angle = datasets[num]
    
    bas_ply=[-60, -45, -30, -15, 0, 15, 30, 45, 60, 90]

    AA1=bas_ply[ply_angle[0]]
    AA2=bas_ply[ply_angle[1]]
    AA3=bas_ply[ply_angle[2]]
    AA4=bas_ply[ply_angle[3]]
    AA5=bas_ply[ply_angle[4]]
    AA6=bas_ply[ply_angle[5]]
    AA7=bas_ply[ply_angle[6]]
    AA8=bas_ply[ply_angle[7]]

    ### ply stacking sequence###
    AAA=[AA1/180.0*PI,AA2/180.0*PI,AA3/180.0*PI,AA4/180.0*PI,AA5/180.0*PI,AA6/180.0*PI,AA7/180.0*PI,AA8/180.0*PI,AA8/180.0*PI,AA7/180.0*PI,AA6/180.0*PI,AA5/180.0*PI,AA4/180.0*PI,AA3/180.0*PI,AA2/180.0*PI,AA1/180.0*PI]
    pi=3.14159265358979

    R=250.0   ##  radius##
    H=510.0   ##  Height##
    td=0.125  #layer thickness##

    TTT=[-td*8,-td*7,-td*6,-td*5,-td*4,-td*3,-td*2,-td*1,td*0,td*1,td*2,td*3,td*4,td*5,td*6,td*7,td*8]

    ###material property###

    E1=123550.0  
    E2=8707.9
    G12=5695.0
    miu12=0.31946

    miu21=miu12*E2/E1
    Q11=E1/(1-miu12*miu21)
    Q12=miu21*E1/(1-miu12*miu21)
    Q22=E2/(1-miu12*miu21)
    Q66=G12

    A11=0.0
    A12=0.0
    A22=0.0
    A66=0.0

    D11=0.0
    D12=0.0
    D22=0.0
    D66=0.0

    for i in range(0,16):
        A11=A11+(Q11*cos(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*sin(AAA[i])**4)*(TTT[i+1]-TTT[i])
        A12=A12+((Q11+Q22-4*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q12*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]-TTT[i])
        A22=A22+(Q11*sin(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*cos(AAA[i])**4)*(TTT[i+1]-TTT[i])
        A66=A66+((Q11+Q22-2*Q12-2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q66*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]-TTT[i])
        D11=D11+(Q11*cos(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*sin(AAA[i])**4)*(TTT[i+1]**3-TTT[i]**3)/3.0
        D12=D12+((Q11+Q22-4*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q12*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]**3-TTT[i]**3)/3.0
        D22=D22+(Q11*sin(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*cos(AAA[i])**4)*(TTT[i+1]**3-TTT[i]**3)/3.0
        D66=D66+((Q11+Q22-2*Q12-2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q66*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]**3-TTT[i]**3)/3.0

    #####bianliang########

    D= 2*R
    L= H

    #xian
    a=[[A11,A12,0],[A12,A22,0],[0,0,A66]]
    b=[[0,0,0],[0,0,0],[0,0,0]]
    d=[[D11,D12,0],[D12,D22,0],[0,0,D66]]

    alpha=PI/L
    beta=2/D

    mm=50
    nn=50
    kmm=0
    knn=0
    kmm11=0
    knn11=0
    F=[[0 for col in range(nn)] for row in range(mm)]
    Fcr=1e16

    for m in range(1,mm+1):
        for n in range(1,nn+1):
            xi11=2*a[0][0]*(m*alpha)**2+2*a[2][2]*(n*beta)**2
            xi12=2*(a[0][1]+a[2][2])*m*alpha*n*beta
            xi13=4*a[0][1]*m*alpha/D-2*b[0][0]*(m*alpha)**3-2*(b[0][1]+2*b[2][2])*m*alpha*(n*beta)**2
            xi22=2*a[1][1]*(n*beta)**2+2*a[2][2]*(m*alpha)**2
            xi23=4*a[1][1]*n*beta/D-2*b[1][1]*(n*beta)**3-2*(b[0][1]+2*b[2][2])*(m*alpha)**2*n*beta
            xi33=4*(d[0][1]+2*d[2][2])*(m*alpha*n*beta)**2+8*a[1][1]/(D**2)\
            +2*d[0][0]*(m*alpha)**4+2*d[1][1]*(n*beta)**4-8*(b[1][1]*(n*beta)**2+b[0][1]*(m*alpha)**2)/D
            xi21=xi12
            xi31=xi13
            xi32=xi23
            det1=xi11*(xi22*xi33-xi32*xi23)-xi12*(xi21*xi33-xi31*xi23)+xi13*(xi21*xi32-xi31*xi22)
            det2=xi11*xi22-xi21*xi12
            Nx=det1/det2/(2*((m*alpha)**2))
            F[m-1][n-1]=Nx*PI*D
            if Fcr>F[m-1][n-1]:
              Fcr=F[m-1][n-1]
              kmm=m
              knn=2*n

    for m in range(1,mm+1):
        xi11=2*a[0][0]*(m*alpha)**2
        xi12=0
        xi13=4*a[0][1]*m*alpha/D-2*b[0][0]*(m*alpha)**3
        xi22=2*a[2][2]*(m*alpha)**2
        xi23=0
        xi33=8*a[1][1]/(D**2)+2*d[0][0]*(m*alpha)**4-8*b[0][1]*(m*alpha)**2/D
        xi21=xi12
        xi31=xi13
        xi32=xi23
        det1=xi11*(xi22*xi33-xi32*xi23)-xi12*(xi21*xi33-xi31*xi23)+xi13*(xi21*xi32-xi31*xi22)
        det2=xi11*xi22-xi21*xi12
        Nx=det1/det2/(2*((m*alpha)**2))
        Fn1=Nx*PI*D
        if Fcr>Fn1:
          Fcr=Fn1
          kmm=m
          knn=1

    return -1.0/(Fcr/100000)**3

# map async parallel 
# pool = mp.Pool(mp.cpu_count())
pool = mp.Pool(processes = 8)

start = time.time()
Fcr_ori = pool.map(ssh, range(data_size))
end = time.time() 
print(end - start) #0.0037827491760253906
# pool.close()
# print(results_map)
# Fcr_min = min(Fcr_ori)
# results_map = []
# for j in range(data_size):
#     results_map.append(Fcr_ori[j]/Fcr_min)
    
results_map = Fcr_ori
# plt.figure()
# plt.hist(results_map,50)
plt.figure()
plt.hist(Fcr_ori,50)
# Out:
# 370.06365489959717
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         2.0000e+00, 1.0000e+00, 2.0000e+00, 9.0000e+00, 9.0000e+00,
#         1.5000e+01, 3.3000e+01, 2.8000e+01, 5.9000e+01, 1.4100e+02,
#         2.7900e+02, 5.1300e+02, 7.9100e+02, 1.2640e+03, 1.8540e+03,
#         2.5620e+03, 3.6740e+03, 5.1480e+03, 6.8510e+03, 9.0940e+03,
#         1.1790e+04, 1.4869e+04, 1.6772e+04, 1.6262e+04, 7.9750e+03]),
#  array([-0.03331636, -0.03269916, -0.03208196, -0.03146477, -0.03084757,
#         -0.03023037, -0.02961317, -0.02899597, -0.02837877, -0.02776158,
#         -0.02714438, -0.02652718, -0.02590998, -0.02529278, -0.02467558,
#         -0.02405839, -0.02344119, -0.02282399, -0.02220679, -0.02158959,
#         -0.02097239, -0.02035519, -0.019738  , -0.0191208 , -0.0185036 ,
#         -0.0178864 , -0.0172692 , -0.016652  , -0.01603481, -0.01541761,
#         -0.01480041, -0.01418321, -0.01356601, -0.01294881, -0.01233162,
#         -0.01171442, -0.01109722, -0.01048002, -0.00986282, -0.00924562,
#         -0.00862843, -0.00801123, -0.00739403, -0.00677683, -0.00615963,
#         -0.00554243, -0.00492523, -0.00430804, -0.00369084, -0.00307364,
#         -0.00245644]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# # Data classification and preprocessing

# %%
results_map_sort = sorted(results_map) # note that sorted change the sort but didn't change the original one
# print(results_map_sort)
median_value = results_map_sort[data_size//2]
print(median_value)

results_map_new = np.zeros((data_size,1))
output_scikit = np.zeros(data_size)

for i in range(data_size):
    if results_map[i] > median_value:
        results_map_new[i,:] = 1
        output_scikit[i] = 1
    else:
        results_map_new[i,:] = 0
        output_scikit[i] = 0

y_data = output_scikit
# Out:
# -0.0046632696953126974

# %% [markdown]
# # Training by classification

# %%
# scikit-learn MLP training 
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import fetch_mldata
from sklearn import preprocessing
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# preprocessing data scale? X is [1,10]
trans_mean = np.mean(datasets)
trans_std = np.std(datasets)

data_scale = 2
if data_scale==0:
    X_data = preprocessing.scale(datasets)
elif data_scale ==1:
    min_max_scaler = preprocessing.MinMaxScaler(feature_range=(0, 1))
    X_data = min_max_scaler.fit_transform(datasets)
elif data_scale ==2:
    scaler = preprocessing.StandardScaler().fit(datasets) # can be used for the following iteration 
    X_data = scaler.transform(datasets)  

# sgd optimizer 
# mlp = MLPClassifier(solver='sgd', activation='relu',alpha=1e-4, hidden_layer_sizes=(128, 128),
#                     random_state=1, max_iter=10000,verbose=True)

mlp = MLPClassifier(solver='adam', activation='relu',alpha=1e-4, hidden_layer_sizes=(128, 128),
                    random_state=1, max_iter=1000,verbose=True,learning_rate = 'adaptive')

# lbfgs - very slow 
# mlp = MLPClassifier(solver='lbfgs', activation='relu',alpha=1e-4,hidden_layer_sizes=(100,100),
#                     random_state=1,max_iter=50,verbose=10,learning_rate_init=.1)
# adam 
# mlp = MLPClassifier(solver='adam', activation='relu',alpha=1e-4,hidden_layer_sizes=(100,100),
#                     random_state=1,max_iter=50,verbose=10,learning_rate_init=.1)

# testing and training data 
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.2,random_state=rs_number)

# training 
mlp.fit(X_train, y_train) 

#testing
y_pred = mlp.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy (train) for %0.1f%% " % (accuracy * 100))

# # cross-validation 
# score_cv = cross_val_score(mlp, X_data, y_data,cv=5)  
# print(score_cv)

## tuning hyperparameters 

# 10000 data, [0.84457771 0.854      0.8385     0.845      0.85992996], default
# 10000 data, [0.82908546 0.835      0.8235     0.8185     0.82391196], feature[1,10] normalization 效果一般
# 10000 data, [0.86206897 0.8605     0.8375     0.854      0.8154077 ], feature[0,1] normalization 效果一般
# 10000 data, [0.84457771 0.854      0.8385     0.845      0.85992996], StandardScaler()
# Out:
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Iteration 1, loss = 0.54449206
# Iteration 2, loss = 0.43414168
# Iteration 3, loss = 0.38125285
# Iteration 4, loss = 0.35034684
# Iteration 5, loss = 0.32891683
# Iteration 6, loss = 0.31363482
# Iteration 7, loss = 0.30066708
# Iteration 8, loss = 0.28923620
# Iteration 9, loss = 0.28207648
# Iteration 10, loss = 0.27420567
# Iteration 11, loss = 0.26802488
# Iteration 12, loss = 0.26093540
# Iteration 13, loss = 0.25505504
# Iteration 14, loss = 0.25033065
# Iteration 15, loss = 0.24490195
# Iteration 16, loss = 0.23991357
# Iteration 17, loss = 0.23439777
# Iteration 18, loss = 0.23008094
# Iteration 19, loss = 0.22583676
# Iteration 20, loss = 0.21969484
# Iteration 21, loss = 0.21576488
# Iteration 22, loss = 0.21026177
# Iteration 23, loss = 0.20631353
# Iteration 24, loss = 0.20201783
# Iteration 25, loss = 0.19433785
# Iteration 26, loss = 0.19322951
# Iteration 27, loss = 0.18824710
# Iteration 28, loss = 0.18336789
# Iteration 29, loss = 0.17864374
# Iteration 30, loss = 0.17652987
# Iteration 31, loss = 0.17120036
# Iteration 32, loss = 0.16904058
# Iteration 33, loss = 0.16647796
# Iteration 34, loss = 0.16376625
# Iteration 35, loss = 0.16053725
# Iteration 36, loss = 0.15632437
# Iteration 37, loss = 0.15682861
# Iteration 38, loss = 0.15283490
# Iteration 39, loss = 0.15099971
# Iteration 40, loss = 0.14927043
# Iteration 41, loss = 0.14661360
# Iteration 42, loss = 0.14558819
# Iteration 43, loss = 0.14285569
# Iteration 44, loss = 0.14031332
# Iteration 45, loss = 0.13792589
# Iteration 46, loss = 0.13744992
# Iteration 47, loss = 0.13562509
# Iteration 48, loss = 0.13445294
# Iteration 49, loss = 0.13398424
# Iteration 50, loss = 0.13168095
# Iteration 51, loss = 0.13025895
# Iteration 52, loss = 0.12670793
# Iteration 53, loss = 0.12519212
# Iteration 54, loss = 0.12565709
# Iteration 55, loss = 0.12425110
# Iteration 56, loss = 0.12161238
# Iteration 57, loss = 0.12058559
# Iteration 58, loss = 0.11819503
# Iteration 59, loss = 0.11738105
# Iteration 60, loss = 0.11661309
# Iteration 61, loss = 0.11451462
# Iteration 62, loss = 0.11294374
# Iteration 63, loss = 0.11194158
# Iteration 64, loss = 0.11354475
# Iteration 65, loss = 0.10953473
# Iteration 66, loss = 0.10916945
# Iteration 67, loss = 0.10727180
# Iteration 68, loss = 0.10672562
# Iteration 69, loss = 0.10499349
# Iteration 70, loss = 0.10572105
# Iteration 71, loss = 0.10242531
# Iteration 72, loss = 0.10136678
# Iteration 73, loss = 0.10056571
# Iteration 74, loss = 0.09981976
# Iteration 75, loss = 0.09976977
# Iteration 76, loss = 0.09800804
# Iteration 77, loss = 0.09664305
# Iteration 78, loss = 0.09609577
# Iteration 79, loss = 0.09455155
# Iteration 80, loss = 0.09336836
# Iteration 81, loss = 0.09288742
# Iteration 82, loss = 0.09220310
# Iteration 83, loss = 0.09451603
# Iteration 84, loss = 0.09124913
# Iteration 85, loss = 0.09168557
# Iteration 86, loss = 0.09214602
# Iteration 87, loss = 0.08760767
# Iteration 88, loss = 0.08905081
# Iteration 89, loss = 0.08902947
# Iteration 90, loss = 0.08725195
# Iteration 91, loss = 0.08748408
# Iteration 92, loss = 0.08596811
# Iteration 93, loss = 0.08573892
# Iteration 94, loss = 0.08555797
# Iteration 95, loss = 0.08391742
# Iteration 96, loss = 0.08294277
# Iteration 97, loss = 0.08327001
# Iteration 98, loss = 0.08219704
# Iteration 99, loss = 0.08147536
# Iteration 100, loss = 0.08122582
# Iteration 101, loss = 0.08157586
# Iteration 102, loss = 0.08161904
# Iteration 103, loss = 0.07831494
# Iteration 104, loss = 0.07933413
# Iteration 105, loss = 0.07999842
# Iteration 106, loss = 0.07783522
# Iteration 107, loss = 0.07758401
# Iteration 108, loss = 0.07871084
# Iteration 109, loss = 0.07568860
# Iteration 110, loss = 0.07657452
# Iteration 111, loss = 0.07646801
# Iteration 112, loss = 0.07613823
# Iteration 113, loss = 0.07594815
# Iteration 114, loss = 0.07604577
# Iteration 115, loss = 0.07637692
# Iteration 116, loss = 0.07300082
# Iteration 117, loss = 0.07395208
# Iteration 118, loss = 0.07268230
# Iteration 119, loss = 0.07309826
# Iteration 120, loss = 0.07254798
# Iteration 121, loss = 0.07341403
# Iteration 122, loss = 0.07181311
# Iteration 123, loss = 0.07088668
# Iteration 124, loss = 0.07177052
# Iteration 125, loss = 0.06985015
# Iteration 126, loss = 0.07085065
# Iteration 127, loss = 0.07069916
# Iteration 128, loss = 0.06895948
# Iteration 129, loss = 0.06842016
# Iteration 130, loss = 0.07030954
# Iteration 131, loss = 0.06710376
# Iteration 132, loss = 0.06977239
# Iteration 133, loss = 0.06842353
# Iteration 134, loss = 0.06744970
# Iteration 135, loss = 0.06677856
# Iteration 136, loss = 0.06784516
# Iteration 137, loss = 0.06726464
# Iteration 138, loss = 0.06536400
# Iteration 139, loss = 0.06951431
# Iteration 140, loss = 0.06546726
# Iteration 141, loss = 0.06555944
# Iteration 142, loss = 0.06619277
# Iteration 143, loss = 0.06553322
# Iteration 144, loss = 0.06341175
# Iteration 145, loss = 0.06640398
# Iteration 146, loss = 0.06516631
# Iteration 147, loss = 0.06412476
# Iteration 148, loss = 0.06492631
# Iteration 149, loss = 0.06466780
# Iteration 150, loss = 0.06253108
# Iteration 151, loss = 0.06320924
# Iteration 152, loss = 0.06382889
# Iteration 153, loss = 0.06394283
# Iteration 154, loss = 0.06115611
# Iteration 155, loss = 0.06239413
# Iteration 156, loss = 0.06375399
# Iteration 157, loss = 0.06112793
# Iteration 158, loss = 0.06088918
# Iteration 159, loss = 0.06326216
# Iteration 160, loss = 0.06049800
# Iteration 161, loss = 0.06056593
# Iteration 162, loss = 0.06087002
# Iteration 163, loss = 0.06104340
# Iteration 164, loss = 0.05980999
# Iteration 165, loss = 0.05877111
# Iteration 166, loss = 0.06071779
# Iteration 167, loss = 0.05895001
# Iteration 168, loss = 0.05793089
# Iteration 169, loss = 0.06060813
# Iteration 170, loss = 0.05811580
# Iteration 171, loss = 0.05856848
# Iteration 172, loss = 0.05743149
# Iteration 173, loss = 0.05747747
# Iteration 174, loss = 0.06010836
# Iteration 175, loss = 0.05851304
# Iteration 176, loss = 0.05687328
# Iteration 177, loss = 0.05559224
# Iteration 178, loss = 0.05651812
# Iteration 179, loss = 0.05463380
# Iteration 180, loss = 0.05652458
# Iteration 181, loss = 0.05553996
# Iteration 182, loss = 0.05687596
# Iteration 183, loss = 0.05671296
# Iteration 184, loss = 0.05657047
# Iteration 185, loss = 0.05605656
# Iteration 186, loss = 0.05544675
# Iteration 187, loss = 0.05658543
# Iteration 188, loss = 0.05494784
# Iteration 189, loss = 0.05317263
# Iteration 190, loss = 0.05332372
# Iteration 191, loss = 0.05510414
# Iteration 192, loss = 0.05277162
# Iteration 193, loss = 0.05412327
# Iteration 194, loss = 0.05528089
# Iteration 195, loss = 0.05411851
# Iteration 196, loss = 0.05411931
# Iteration 197, loss = 0.05285163
# Iteration 198, loss = 0.05204870
# Iteration 199, loss = 0.05310317
# Iteration 200, loss = 0.05354774
# Iteration 201, loss = 0.05283698
# Iteration 202, loss = 0.05201429
# Iteration 203, loss = 0.05330833
# Iteration 204, loss = 0.05323617
# Iteration 205, loss = 0.05271719
# Iteration 206, loss = 0.05058990
# Iteration 207, loss = 0.05006239
# Iteration 208, loss = 0.05371224
# Iteration 209, loss = 0.04963312
# Iteration 210, loss = 0.05114004
# Iteration 211, loss = 0.05262727
# Iteration 212, loss = 0.05053941
# Iteration 213, loss = 0.05055114
# Iteration 214, loss = 0.05106603
# Iteration 215, loss = 0.04974538
# Iteration 216, loss = 0.04875360
# Iteration 217, loss = 0.04955757
# Iteration 218, loss = 0.04994009
# Iteration 219, loss = 0.04825264
# Iteration 220, loss = 0.04916110
# Iteration 221, loss = 0.05079871
# Iteration 222, loss = 0.04792662
# Iteration 223, loss = 0.04676868
# Iteration 224, loss = 0.04856818
# Iteration 225, loss = 0.04903613
# Iteration 226, loss = 0.04900050
# Iteration 227, loss = 0.04871795
# Iteration 228, loss = 0.04909956
# Iteration 229, loss = 0.04807726
# Iteration 230, loss = 0.04846867
# Iteration 231, loss = 0.04651130
# Iteration 232, loss = 0.04657374
# Iteration 233, loss = 0.04760675
# Iteration 234, loss = 0.04858154
# Iteration 235, loss = 0.04607207
# Iteration 236, loss = 0.04850446
# Iteration 237, loss = 0.04541597
# Iteration 238, loss = 0.04849885
# Iteration 239, loss = 0.04600768
# Iteration 240, loss = 0.04668792
# Iteration 241, loss = 0.04859051
# Iteration 242, loss = 0.04775403
# Iteration 243, loss = 0.04511188
# Iteration 244, loss = 0.04404377
# Iteration 245, loss = 0.04462956
# Iteration 246, loss = 0.04488659
# Iteration 247, loss = 0.04444921
# Iteration 248, loss = 0.04634378
# Iteration 249, loss = 0.04711284
# Iteration 250, loss = 0.04636392
# Iteration 251, loss = 0.04570827
# Iteration 252, loss = 0.04316944
# Iteration 253, loss = 0.04452346
# Iteration 254, loss = 0.04565961
# Iteration 255, loss = 0.04675752
# Iteration 256, loss = 0.04327955
# Iteration 257, loss = 0.04689828
# Iteration 258, loss = 0.04290003
# Iteration 259, loss = 0.04596584
# Iteration 260, loss = 0.04331055
# Iteration 261, loss = 0.04394915
# Iteration 262, loss = 0.04380551
# Iteration 263, loss = 0.04312548
# Iteration 264, loss = 0.04216790
# Iteration 265, loss = 0.04336003
# Iteration 266, loss = 0.04224678
# Iteration 267, loss = 0.04456114
# Iteration 268, loss = 0.04574476
# Iteration 269, loss = 0.04160959
# Iteration 270, loss = 0.04207769
# Iteration 271, loss = 0.04246727
# Iteration 272, loss = 0.04095866
# Iteration 273, loss = 0.04145127
# Iteration 274, loss = 0.04048631
# Iteration 275, loss = 0.04236652
# Iteration 276, loss = 0.04180892
# Iteration 277, loss = 0.04253513
# Iteration 278, loss = 0.04142023
# Iteration 279, loss = 0.04116388
# Iteration 280, loss = 0.04014708
# Iteration 281, loss = 0.04061087
# Iteration 282, loss = 0.04305561
# Iteration 283, loss = 0.04122076
# Iteration 284, loss = 0.04131506
# Iteration 285, loss = 0.03980718
# Iteration 286, loss = 0.04247968
# Iteration 287, loss = 0.04253638
# Iteration 288, loss = 0.03948727
# Iteration 289, loss = 0.04093298
# Iteration 290, loss = 0.04164687
# Iteration 291, loss = 0.03999898
# Iteration 292, loss = 0.03889396
# Iteration 293, loss = 0.03940572
# Iteration 294, loss = 0.03904576
# Iteration 295, loss = 0.03888343
# Iteration 296, loss = 0.04077556
# Iteration 297, loss = 0.04049389
# Iteration 298, loss = 0.03873317
# Iteration 299, loss = 0.03801135
# Iteration 300, loss = 0.04111663
# Iteration 301, loss = 0.03969395
# Iteration 302, loss = 0.03958097
# Iteration 303, loss = 0.04257837
# Iteration 304, loss = 0.03715324
# Iteration 305, loss = 0.04101085
# Iteration 306, loss = 0.03683695
# Iteration 307, loss = 0.03938227
# Iteration 308, loss = 0.03715330
# Iteration 309, loss = 0.03711193
# Iteration 310, loss = 0.03773668
# Iteration 311, loss = 0.04008368
# Iteration 312, loss = 0.03956927
# Iteration 313, loss = 0.04044747
# Iteration 314, loss = 0.03591702
# Iteration 315, loss = 0.03433400
# Iteration 316, loss = 0.04087202
# Iteration 317, loss = 0.03712894
# Iteration 318, loss = 0.03776923
# Iteration 319, loss = 0.03628520
# Iteration 320, loss = 0.03685897
# Iteration 321, loss = 0.03935165
# Iteration 322, loss = 0.03838919
# Iteration 323, loss = 0.03770081
# Iteration 324, loss = 0.03541095
# Iteration 325, loss = 0.03664185
# Iteration 326, loss = 0.03736871
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Accuracy (train) for 95.9%

# %% [markdown]
# # ML rank VS FEM rank

# %%
sort_index_FEM = np.argsort(results_map)
probs = mlp.predict_proba(X_data)
sort_index_mlp = np.argsort(probs[:][:,1])

sort_FEM = sort_index_FEM.tolist()
sort_mlp = sort_index_mlp.tolist()

rank_mlp = []
for j in range(data_size):
    rank_fem = sort_FEM[j]
    rank_mlp0 = sort_mlp.index(rank_fem)
    rank_mlp.append(rank_mlp0)


plt.figure()
plt.plot(range(data_size),rank_mlp,'.')

# %% [markdown]
# # Stochastic Optimization

# %%
# multiple loop training but no call FEM data collection 

loop = 10
X_loop = X_data # scale data, 50000
X_ori = datasets # orial data, 50000

for i in range(loop):
    print(i)
    # classification probability 
    probs_all = mlp.predict_proba(X_loop)
    sort_index_mlp = np.argsort(probs_all[:][:,1])

    # top 10% selection 
    top_10 = X_loop[sort_index_mlp[int(data_size*0.9):data_size]]
    top_10_ori = X_ori[sort_index_mlp[int(data_size*0.9):data_size]]
#     print(top_10_ori)

    # random selection 90%
    if random_selection==0:
        ''' random selection'''
        data_random = np.random.randint(1, 10, size=[int(data_size*0.9), 8])
    else:
        '''latin hypercube sampling'''

    X_90_scale = scaler.transform(data_random) 
    X_90_ori = data_random
    X_loop = np.concatenate((X_90_scale, top_10), axis=0)
    X_ori = np.concatenate((X_90_ori, top_10_ori), axis=0)
# Out:
# 0
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 1
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 2
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 3
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 4
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 5
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 6
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 7
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 8
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# 9
# /Users/jiaxinzhang/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
datasets_test = top_10_ori

def ssh_test(num):
#     global datasets
#     arr = np.random.randint(1, 10, size=[data_size, 8])
#     datasets = arr.tolist()
    ply_angle = datasets_test[num]
    
    bas_ply=[-60, -45, -30, -15, 0, 15, 30, 45, 60, 90]

    AA1=bas_ply[ply_angle[0]]
    AA2=bas_ply[ply_angle[1]]
    AA3=bas_ply[ply_angle[2]]
    AA4=bas_ply[ply_angle[3]]
    AA5=bas_ply[ply_angle[4]]
    AA6=bas_ply[ply_angle[5]]
    AA7=bas_ply[ply_angle[6]]
    AA8=bas_ply[ply_angle[7]]

    ### ply stacking sequence###
    AAA=[AA1/180.0*PI,AA2/180.0*PI,AA3/180.0*PI,AA4/180.0*PI,AA5/180.0*PI,AA6/180.0*PI,AA7/180.0*PI,AA8/180.0*PI,AA8/180.0*PI,AA7/180.0*PI,AA6/180.0*PI,AA5/180.0*PI,AA4/180.0*PI,AA3/180.0*PI,AA2/180.0*PI,AA1/180.0*PI]
    pi=3.14159265358979

    R=250.0   ##  radius##
    H=510.0   ##  Height##
    td=0.125  #layer thickness##

    TTT=[-td*8,-td*7,-td*6,-td*5,-td*4,-td*3,-td*2,-td*1,td*0,td*1,td*2,td*3,td*4,td*5,td*6,td*7,td*8]

    ###material property###

    E1=123550.0  
    E2=8707.9
    G12=5695.0
    miu12=0.31946

    miu21=miu12*E2/E1
    Q11=E1/(1-miu12*miu21)
    Q12=miu21*E1/(1-miu12*miu21)
    Q22=E2/(1-miu12*miu21)
    Q66=G12

    A11=0.0
    A12=0.0
    A22=0.0
    A66=0.0

    D11=0.0
    D12=0.0
    D22=0.0
    D66=0.0

    for i in range(0,16):
        A11=A11+(Q11*cos(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*sin(AAA[i])**4)*(TTT[i+1]-TTT[i])
        A12=A12+((Q11+Q22-4*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q12*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]-TTT[i])
        A22=A22+(Q11*sin(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*cos(AAA[i])**4)*(TTT[i+1]-TTT[i])
        A66=A66+((Q11+Q22-2*Q12-2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q66*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]-TTT[i])
        D11=D11+(Q11*cos(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*sin(AAA[i])**4)*(TTT[i+1]**3-TTT[i]**3)/3.0
        D12=D12+((Q11+Q22-4*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q12*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]**3-TTT[i]**3)/3.0
        D22=D22+(Q11*sin(AAA[i])**4+2*(Q12+2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q22*cos(AAA[i])**4)*(TTT[i+1]**3-TTT[i]**3)/3.0
        D66=D66+((Q11+Q22-2*Q12-2*Q66)*sin(AAA[i])**2*cos(AAA[i])**2+Q66*(sin(AAA[i])**4+cos(AAA[i])**4))*(TTT[i+1]**3-TTT[i]**3)/3.0

    #####bianliang########

    D= 2*R
    L= H

    #xian
    a=[[A11,A12,0],[A12,A22,0],[0,0,A66]]
    b=[[0,0,0],[0,0,0],[0,0,0]]
    d=[[D11,D12,0],[D12,D22,0],[0,0,D66]]

    alpha=PI/L
    beta=2/D

    mm=50
    nn=50
    kmm=0
    knn=0
    kmm11=0
    knn11=0
    F=[[0 for col in range(nn)] for row in range(mm)]
    Fcr=1e16

    for m in range(1,mm+1):
        for n in range(1,nn+1):
            xi11=2*a[0][0]*(m*alpha)**2+2*a[2][2]*(n*beta)**2
            xi12=2*(a[0][1]+a[2][2])*m*alpha*n*beta
            xi13=4*a[0][1]*m*alpha/D-2*b[0][0]*(m*alpha)**3-2*(b[0][1]+2*b[2][2])*m*alpha*(n*beta)**2
            xi22=2*a[1][1]*(n*beta)**2+2*a[2][2]*(m*alpha)**2
            xi23=4*a[1][1]*n*beta/D-2*b[1][1]*(n*beta)**3-2*(b[0][1]+2*b[2][2])*(m*alpha)**2*n*beta
            xi33=4*(d[0][1]+2*d[2][2])*(m*alpha*n*beta)**2+8*a[1][1]/(D**2)\
            +2*d[0][0]*(m*alpha)**4+2*d[1][1]*(n*beta)**4-8*(b[1][1]*(n*beta)**2+b[0][1]*(m*alpha)**2)/D
            xi21=xi12
            xi31=xi13
            xi32=xi23
            det1=xi11*(xi22*xi33-xi32*xi23)-xi12*(xi21*xi33-xi31*xi23)+xi13*(xi21*xi32-xi31*xi22)
            det2=xi11*xi22-xi21*xi12
            Nx=det1/det2/(2*((m*alpha)**2))
            F[m-1][n-1]=Nx*PI*D
            if Fcr>F[m-1][n-1]:
              Fcr=F[m-1][n-1]
              kmm=m
              knn=2*n

    for m in range(1,mm+1):
        xi11=2*a[0][0]*(m*alpha)**2
        xi12=0
        xi13=4*a[0][1]*m*alpha/D-2*b[0][0]*(m*alpha)**3
        xi22=2*a[2][2]*(m*alpha)**2
        xi23=0
        xi33=8*a[1][1]/(D**2)+2*d[0][0]*(m*alpha)**4-8*b[0][1]*(m*alpha)**2/D
        xi21=xi12
        xi31=xi13
        xi32=xi23
        det1=xi11*(xi22*xi33-xi32*xi23)-xi12*(xi21*xi33-xi31*xi23)+xi13*(xi21*xi32-xi31*xi22)
        det2=xi11*xi22-xi21*xi12
        Nx=det1/det2/(2*((m*alpha)**2))
        Fn1=Nx*PI*D
        if Fcr>Fn1:
          Fcr=Fn1
          kmm=m
          knn=1

    return Fcr

# %%
# pool = mp.Pool(processes = 8)
# out_opt_value = pool.map(ssh_test, range(int(data_size*0.1)))
# print(out_opt_value)
# plt.figure()
# plt.hist(out_opt_value)

out_opt_proba = mlp.predict_proba(top_10)
print(out_opt_proba[:][:,1])
plt.figure()
plt.hist(out_opt_proba[:][:,1])


plt.figure()
plt.hist(results_map)
# print(out_opt_value)
# print(out_opt_proba[:][:,1])
# print(np.shape(datasets))

# print(out_opt_value)
print(np.mean(out_opt_value))
print(np.std(out_opt_value))
print(min(out_opt_value))
print(max(out_opt_value))
# Out:
# [0.99999999 0.99999999 0.99999999 ... 1.         1.         1.        ]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5134f8480881> in <module>
#      18
#      19 # print(out_opt_value)
# ---> 20 print(np.mean(out_opt_value))
#      21 print(np.std(out_opt_value))
#      22 print(min(out_opt_value))
#
# NameError: name 'out_opt_value' is not defined

# %%
print(max(results_map))
print(np.mean(results_map))
print(np.std(results_map))
